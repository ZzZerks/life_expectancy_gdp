# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# LOAD DATA
df = pd.read_csv("all_data.csv")
print(df.head(10))

df = df.rename({"Life expectancy at birth (years)":"LEABY"}, axis = "columns")
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10
# 5   Chile  2005                              78.4  1.229650e+11
# 6   Chile  2006                              78.9  1.547880e+11
# 7   Chile  2007                              78.9  1.736060e+11
# 8   Chile  2008                              79.6  1.796380e+11
# 9   Chile  2009                              79.3  1.723890e+11

# %%
#Sorted and printed counries and years for better understanding
countries = set(df["Country"])
for country in sorted(countries):
    sum_countries = len(countries) 
    print(country)
print("Period:",df.Year.unique())
print("We have", sum_countries, "countries for observation.")
#Later it turned out that "UNITED STATES OF AMERICA" took up too much space, it was decided to shorten it to "USA"
df['Country'] = df['Country'].replace('United States of America', 'USA')
# Out:
# Chile
# China
# Germany
# Mexico
# United States of America
# Zimbabwe
# Period: [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]
# We have 6 countries for observation.

# %%
#general statistic for gdp
plt.figure(figsize=(8, 6))
sns.histplot(df.GDP, bins=20, kde=False, color='skyblue')
plt.xlabel("GDP in Trillions of U.S. Dollars")
plt.title("Distribution of GDP")
plt.show()

# %%
#general statistic for Life expectancy
plt.figure(figsize=(10, 10))
sns.displot(df.LEABY)
plt.xlabel("Life expectancy at birth (years)");

# %% [markdown]
# # This data does not provide us with any useful information.

# %%
data_mean = df.drop("Year", axis = 1).groupby("Country").mean().reset_index()
plt.figure(figsize=(8,6))
sns.barplot(x="LEABY", y="Country", data=data_mean, order=data_mean
            .sort_values('LEABY', ascending=False)['Country'], palette='Reds')
plt.xlabel("Life expectancy at birth (years)");

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="GDP", y="Country", data=data_mean, order=data_mean
            .sort_values('GDP', ascending=False)['Country'], palette='viridis')
plt.xlabel("GDP in Trillions of U.S. Dollars")
plt.title("Average GDP by Country")
# Out:
# Text(0.5, 1.0, 'Average GDP by Country')

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Year', y='GDP', hue='Country', data = df)
plt.legend()
plt.title("GDP in Trillions of U.S. Dollars by Country")
plt.xlabel('Year')
plt.ylabel("GDP in Trillions of U.S. Dollars");
plt.legend(loc='center left', bbox_to_anchor=(1, .5))

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Year', y='LEABY', hue='Country', data=df)
plt.title('Life Expectancy Over Time by Country')
plt.xlabel('Year')
plt.ylabel('Life Expectancy at Birth (years)')
plt.legend(loc='center left', bbox_to_anchor=(1, .5))

# %%
graphGDP = sns.FacetGrid(df, col="Country", col_wrap=3, col_order=sorted(df['Country'].unique()), 
                         hue="Country", sharey=False, sharex=False)

graphGDP = (graphGDP.map(sns.lineplot, "Year", "GDP")
            .add_legend(title="Country", loc='upper left', bbox_to_anchor=(.9, .7), borderaxespad=0.)
            .set_axis_labels("Year", "GDP in Trillions of U.S. Dollars"))

# %%
graphGDP = sns.FacetGrid(df, col="Country", col_wrap=3, col_order=sorted(df['Country'].unique()), 
                         hue="Country", sharey=False, sharex=False)

graphGDP = (graphGDP.map(sns.lineplot, "Year", "LEABY")
            .add_legend(loc='upper left', bbox_to_anchor=(.9, .7), borderaxespad=0.)
            .set_axis_labels("Year", "Life expectancy at birth (years)"))

# %%
#At the end of the project, I realized that I could improve. 
#But for now I will leave everything as it is. 
#A lot of things could be automated

#Thank you
